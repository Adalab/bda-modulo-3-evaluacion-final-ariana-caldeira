# %% [markdown]
# # DA Módulo 3: Ejercicio de evaluación final
#
# - Antes de empezar, hay que crear un nuevo repositorio desde GitHub Classroom usando este [enlace](https://classroom.github.com/a/XPQNhyyO). Una vez creado, hay que clonar en nuestro ordenador y en la carpeta creada empezaremos a trabajar en el ejercicio.
#
# - Puedes usar recursos externos, incluyendo internet y materiales de referencia o tus propias notas.
#
# ## Los Datos
#
# Los  datos que se proporciona consisten en dos conjuntos de archivos que, en conjunto, describen el comportamiento de los clientes dentro de un programa de lealtad de una aerolínea.
#
# ### Customer Flight Analysis.csv
#
# Este archivo contiene información sobre la actividad de vuelo de los clientes, incluyendo el número de vuelos reservados, la distancia volada, puntos acumulados y redimidos, y costos asociados a los puntos redimidos
#
# - **Loyalty Number:** Este atributo representa un identificador único para cada cliente dentro del programa de lealtad de la aerolínea. Cada número de lealtad corresponde a un cliente específico.
# - **Year:** Indica el año en el cual se registraron las actividades de vuelo para el cliente.
# - **Month:** Representa el mes del año (de 1 a 12) en el cual ocurrieron las actividades de vuelo.
# - **Flights Booked:** Número total de vuelos reservados por el cliente en ese mes específico.
# - **Flights with Companions:** Número de vuelos reservados en los cuales el cliente viajó con acompañantes.
# - **Total Flights:** El número total de vuelos que el cliente ha realizado, que puede incluir vuelos reservados en meses anteriores.
# - **Distance:** La distancia total (presumiblemente en millas o kilómetros) que el cliente ha volado durante el mes.
# - **Points Accumulated:** Puntos acumulados por el cliente en el programa de lealtad durante el mes, con base en la distancia volada u otros factores.
# - **Points Redeemed:** Puntos que el cliente ha redimido en el mes, posiblemente para obtener beneficios como vuelos gratis, mejoras, etc.
# - **Dollar Cost Points Redeemed:** El valor en dólares de los puntos que el cliente ha redimido durante el mes.
#
# ### Customer Loyalty History.csv
#
# Este archivo proporciona un perfil detallado de los clientes, incluyendo su ubicación, nivel educativo, ingresos, estado civil, y detalles sobre su membresía en el programa de lealtad (como el tipo de tarjeta, valor de vida del cliente, y fechas de inscripción y cancelación).
#
# - **Loyalty Number:** Identificador único del cliente dentro del programa de lealtad. Este número permite correlacionar la información de este archivo con el archivo de actividad de vuelos.
# - **Country:** País de residencia del cliente.
# - **Province:** Provincia o estado de residencia del cliente (aplicable a países con divisiones provinciales o estatales, como Canadá).
# - **City:** Ciudad de residencia del cliente.
# - **Postal Code:** Código postal del cliente.
# - **Gender:** Género del cliente (ej. Male para masculino y Female para femenino).
# - **Education:** Nivel educativo alcanzado por el cliente (ej. Bachelor para licenciatura, College para estudios universitarios o técnicos, etc.).
# - **Salary:** Ingreso anual estimado del cliente.
# - **Marital Status:** Estado civil del cliente (ej. Single para soltero, Married para casado, Divorced para divorciado, etc.).
# - **Loyalty Card:** Tipo de tarjeta de lealtad que posee el cliente. Esto podría indicar distintos niveles o categorías dentro del programa de lealtad.
# - **CLV (Customer Lifetime Value):** Valor total estimado que el cliente aporta a la empresa durante toda la relación que mantiene con ella.
# - **Enrollment Type:** Tipo de inscripción del cliente en el programa de lealtad (ej. Standard).
# - **Enrollment Year:** Año en que el cliente se inscribió en el programa de lealtad.
# - **Enrollment Month:** Mes en que el cliente se inscribió en el programa de lealtad.
# - **Cancellation Year:** Año en que el cliente canceló su membresía en el programa de lealtad, si aplica.
# - **Cancellation Month:** Mes en que el cliente canceló su membresía en el programa de lealtad, si aplica.
#
#
# ## Normas
#
# Este ejercicio está pensado para que lo realices de forma individual en clase, pero podrás consultar tus dudas con la profesora y tus compañeras si lo consideras necesario. Ellas no te darán directamente la solución de tu duda, pero sí pistas para poder solucionarla. Aún facilitando la comunicación entre compañeras, durante la prueba no debes copiar código de otra persona ni acceder a su portátil. Confiamos en tu responsabilidad.
#
# La evaluación es una buena oportunidad para conocer cómo estás progresando, saber qué temas debes reforzar durante las siguientes semanas y cuáles dominas. Te recomendamos que te sientas cómoda con el ejercicio que entregues y no envíes cosas copiadas que no entiendas.
#
# Si detectamos que has entregado código que no es tuyo, no entiendes y no lo puedes defender, pasarás directamente a la re-evaluación del módulo. Tu objetivo no debería ser pasar la evaluación sino convertirte en analista de datos, y esto debes tenerlo claro en todo momento.
#
# Una vez entregado el ejercicio realizarás una revisión del mismo con la profesora (20 minutos), que se asemenjará a una entrevista técnica: te pedirá que expliques las decisiones tomadas para realizarlo.
#
# Es una oportunidad para practicar la dinámica de una entrevista técnica donde te van a proponer cambios sobre tu código que no conoces a priori. Si evitas que otras compañeras te den pistas sobre la dinámica de feedback, podrás aprovecharlo como una práctica y pasar los nervios con la profesora en lugar de en tu primera entrevista de trabajo.
#
# Al final tendrás un feedback sobre aspectos a destacar y a mejorar en tu ejercicio, y sabrás qué objetivos de aprendizaje has supera
#
# ## Criterios de evaluación
#
# Vamos a listar los criterios de evaluación de este ejercicio. Si no superas al menos el 80% de estos criterios o no has superado algún criterio clave (marcados con \*) te pediremos que realices una re-evaluación con el fin de que termines el curso mejor preparada y enfrentes tu primera experiencia profesional con más seguridad. En caso contrario, estás aprendiendo al ritmo que hemos pautado para poder afrontar los conocimientos del siguiente módulo.
#
# - Análisis Exploratorio de los datos.*
# - Gestión de nulos. *
# - Visualización de datos con matplotlib y seaborn.*
# - Estadística descriptiva.
#
# ### Otros criterios a tener en cuenta
#
# - El repositorio de GitHub debe tener README explicando muy brevemente el proyecto.
# - Uso de buenas prácticas en el código: comentarios, legibilidad, orden, etc.
# - Uso de git: commits descriptivos.
#
# ¡Al turrón!

# %% [markdown]
# ##  Ejercicio

# %%
import pandas as pd
import numpy as np

# Librerías de visualización
import seaborn as sns
import matplotlib.pyplot as plt

# Visualizar todas las columnas de los DataFrames
pd.set_option('display.max_columns', None)

# Importo mi carpeta src que tiene funciones de soporte para analisis EDA
from src import eda_soporte as eda_sp

# %% [markdown]
# #### Fase 1: Exploración y Limpieza

# %% [markdown]
# #### 1. **Exploración Inicial:**
#
#    - Realiza una exploración inicial de los datos para identificar posibles problemas, como valores nulos, atípicos o datos faltantes en las columnas relevantes.
#
#    - Utiliza funciones de Pandas para obtener información sobre la estructura de los datos, la presencia de valores nulos y estadísticas básicas de las columnas involucradas.
#
#    - Une los dos conjuntos de datos de la forma más eficiente.

# %%
# Primero cargo los dataframes y leo las 2 primeras líneas

df_activity = pd.read_csv("Customer Flight Activity.csv")
df_activity.head(2)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0

# %%
df_loyalty = pd.read_csv("Customer Loyalty History.csv")
df_loyalty.head(2)
# Out:
#    Loyalty Number Country Province      City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario   Toronto     M2Z 4K1  Female  Bachelor
# 1          549612  Canada  Alberta  Edmonton     T3G 6Y6    Male   College
#
#     Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  83236.0        Married         Star  3839.14        Standard
# 1      NaN       Divorced         Star  3839.61        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN

# %%
# Llamo a la función que cree para hacer un primer analisis EDA

print("Customer Flight Activity")
eda_sp.eda_1(df_activity)
# Out:
# Customer Flight Activity
# 🔍 EXPLORACIÓN RÁPIDA EDA
#
# ____ DIMENSIONES ____
# Filas: 405624 | Columnas: 10
#
# ____ TIPO DE DATOS ____
# Loyalty Number                   int64
# Year                             int64
# Month                            int64
# Flights Booked                   int64
# Flights with Companions          int64
# Total Flights                    int64
# Distance                         int64
# Points Accumulated             float64
# Points Redeemed                  int64
# Dollar Cost Points Redeemed      int64
# dtype: object
#
# ____ DUPLICADOS ____
# 1864
#
# ____ % DE NULOS ____
# Loyalty Number                 0.0
# Year                           0.0
# Month                          0.0
# Flights Booked                 0.0
# Flights with Companions        0.0
# Total Flights                  0.0
# Distance                       0.0
# Points Accumulated             0.0
# Points Redeemed                0.0
# Dollar Cost Points Redeemed    0.0
# ...

# %%
# Investigando los valores duplicados del df_activity filtrando por la columna de 'Loyalty Number'

df_activity[df_activity['Loyalty Number'].duplicated(keep=False)].sort_values("Loyalty Number").head(5)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 388723          100018  2018     12              17                        6
# 185911          100018  2017     12               6                        0
# 101406          100018  2017      7              10                        0
# 287317          100018  2018      6               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0                   3      1521               152.0                0
# 388723             23      4945               494.0                0
# 185911              6      1908               190.0                0
# 101406             10      3870               387.0                0
# 287317              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 0                                 0
# ...

# %%
# Investigando si la columna 'Points Accumulated' está bien como float o si debemos convertir a int

df_activity['Points Accumulated'].value_counts().tail(3)
# Out:
# Points Accumulated
# 10.8     1
# 565.5    1
# 626.0    1
# Name: count, dtype: int64

# %%
# Year, apenas contiene datos de 2 años

df_activity['Year'].value_counts()
# Out:
# Year
# 2017    202812
# 2018    202812
# Name: count, dtype: int64

# %%
# FUNCIÓN EXPLORACIÓN PARA COLUMNAS NUMÉRICAS

# Las columnas 'Loyalty Number', 'Year' y 'Month' aunque su tipo de dato sea int64, en realidad,
# son columnas categóricas ordinales y no podemos incluirlas en el analisis estadístico de variables numéricas

# voy crear un df solo con las columnas numéricas que me interesan analizar sus datos estadísticos
# las organizé en este orden porque quiero 'emparejar' la visualización
df_num = df_activity[['Distance', 'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed', 'Flights Booked', 'Total Flights', 'Flights with Companions']]

# %%
eda_sp.eda_num(df_num)
# Out:
#
# 🔍 ANALIZANDO COLUMNAS NUMÉRICAS
# Distance, Points Accumulated, Points Redeemed, Dollar Cost Points Redeemed, Flights Booked, Total Flights, Flights with Companions
# ________________________________________________
#
# 📊 ESTADÍSTICAS DESCRIPTIVAS NUMÉRICAS
#
#                              Mínimo  Máximo    Media  Moda  Mediana (50%)
# Distance                        0.0  6293.0  1208.88   0.0          488.0
# Points Accumulated              0.0   676.5   123.69   0.0           50.0
# Points Redeemed                 0.0   876.0    30.70   0.0            0.0
# Dollar Cost Points Redeemed     0.0    71.0     2.48   0.0            0.0
# Flights Booked                  0.0    21.0     4.12   0.0            1.0
# Total Flights                   0.0    32.0     5.15   0.0            1.0
# Flights with Companions         0.0    11.0     1.03   0.0            0.0
#
#                              Q1 (25%)  Q3 (75%)  IQR (Q3-Q1)
# Distance                          0.0    2336.0       2336.0
# ...

# %% [markdown]
# CONCLUSIONES ANÁLISIS ACTIVITY:
# - No hay valores duplicados. El 'Loyalty Number' aparece repetido várias veces porque son registros de várias compras de vuelos por parte del mismo cliente.
# - La columna 'Points Accumulated' contiene valores decimales, su tipo de dato float está correcto.
# - Las columnas 'Loyalty Number', 'Year' y 'Month' son variables categóricas ordinales, todas las demás columnas de esta tabla son numéricas.
# - No hay nulos.
# - No hay columnas con valores únicos.
# - No hay trabajo de limpieza para hacer aquí.
# - En la visualización de los boxplot se puede entender que:
#     - hay correlacción entre 'Distance' y 'Points Accumulated'
#     - sobre el uso y canje de puntos la mayoría de los valores son 0 y los otros valores aparecen como outliers porque están muy lejos del resto.

# %%
# Empiezo a explorar el otro df
df_loyalty.head(2)
# Out:
#    Loyalty Number Country Province      City Postal Code  Gender Education  \
# 0          480934  Canada  Ontario   Toronto     M2Z 4K1  Female  Bachelor
# 1          549612  Canada  Alberta  Edmonton     T3G 6Y6    Male   College
#
#     Salary Marital Status Loyalty Card      CLV Enrollment Type  \
# 0  83236.0        Married         Star  3839.14        Standard
# 1      NaN       Divorced         Star  3839.61        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 2                NaN                 NaN
# 1             2016                 3                NaN                 NaN

# %%
# Vuelvo a usar mi función para una primera exploración EDA

print("Customer Loyalty History")
eda_sp.eda_1(df_loyalty)
# Out:
# Customer Loyalty History
# 🔍 EXPLORACIÓN RÁPIDA EDA
#
# ____ DIMENSIONES ____
# Filas: 16737 | Columnas: 16
#
# ____ TIPO DE DATOS ____
# Loyalty Number          int64
# Country                object
# Province               object
# City                   object
# Postal Code            object
# Gender                 object
# Education              object
# Salary                float64
# Marital Status         object
# Loyalty Card           object
# CLV                   float64
# Enrollment Type        object
# Enrollment Year         int64
# Enrollment Month        int64
# Cancellation Year     float64
# Cancellation Month    float64
# dtype: object
#
# ____ DUPLICADOS ____
# 0
#
# ____ % DE NULOS ____
# Loyalty Number         0.00
# Country                0.00
# Province               0.00
# City                   0.00
# Postal Code            0.00
# Gender                 0.00
# Education              0.00
# Salary                25.32
# Marital Status         0.00
# ...

# %%
# Tipo de dato como FLOAT y deberían ser INT : 'Cancellation Year' y 'Cancellation Month'

for d in ['Cancellation Month', 'Cancellation Year']:
    print(df_loyalty[d].value_counts().head(2))
    print(" ")
# Out:
# Cancellation Month
# 12.0    213
# 11.0    212
# Name: count, dtype: int64
#
# Cancellation Year
# 2018.0    645
# 2017.0    506
# Name: count, dtype: int64

# %%
# Confirmando si no hay duplicados

df_loyalty['Loyalty Number'].duplicated().sum()
# Out:
# np.int64(0)

# %%
# Esta columna solo tiene 1 valor único

df_loyalty['Country'].value_counts()
# Out:
# Country
# Canada    16737
# Name: count, dtype: int64

# %%
# Excluyo de este analisis las columnas que no me interesan 
# investigar: Loyalty Number, Country, Postal Code

# COLUMNAS NUMÉRICAS que quiero explorar estadísticamente
df_loyal_num = df_loyalty[['Salary', 'CLV']]

# FUNCIÓN EXPLORACIÓN PARA COLUMNAS NUMÉRICAS
eda_sp.eda_num(df_loyal_num)
# Out:
#
# 🔍 ANALIZANDO COLUMNAS NUMÉRICAS
# Salary, CLV
# ________________________________________________
#
# 📊 ESTADÍSTICAS DESCRIPTIVAS NUMÉRICAS
#
#           Mínimo     Máximo     Media       Moda  Mediana (50%)
# Salary -58486.00  407228.00  79245.61  101933.00       73455.00
# CLV      1898.01   83325.38   7988.90    8564.77        5780.18
#
#         Q1 (25%)  Q3 (75%)  IQR (Q3-Q1)
# Salary  59246.50  88517.50     29271.00
# CLV      3980.84   8940.58      4959.74
#
# ________________________________________________
#
# 🗳️ BOXPLOTS PARA DETECTAR OUTLIERS Y DISTRIBUCIÓN
#  -- análisis terminado --

# %%
# Identifiqué valores negativos en la columna 'Salary'
# Exploro esos valores negativos

df_loyalty['Salary'].min()
# Out:
# -58486.0

# %%
# Filtro las filas con salario negativo

negativos = df_loyalty[df_loyalty['Salary'] < 0]
negativos.head(2)
# Out:
#       Loyalty Number Country          Province       City Postal Code  Gender  \
# 1082          542976  Canada            Quebec   Montreal     H2Y 4R4    Male
# 1894          959977  Canada  British Columbia  Vancouver     V5R 1W3  Female
# 2471          232755  Canada  British Columbia  Vancouver     V1E 4R6  Female
#
#                  Education   Salary Marital Status Loyalty Card       CLV  \
# 1082  High School or Below -49830.0       Divorced         Star  24127.50
# 1894              Bachelor -12497.0        Married       Aurora   9453.00
# 2471              Bachelor -46683.0         Single         Nova   4787.81
#
#      Enrollment Type  Enrollment Year  Enrollment Month  Cancellation Year  \
# 1082  2018 Promotion             2018                 3                NaN
# 1894  2018 Promotion             2018                 3                NaN
# 2471  2018 Promotion             2018                 3                NaN
#
#       Cancellation Month
# ...

# %%
negativos['Salary'].value_counts()
# Out:
# Salary
# -49830.0    1
# -12497.0    1
# -46303.0    1
# -19332.0    1
# -39503.0    1
# -47310.0    1
# -26322.0    1
# -46470.0    1
# -9081.0     1
# -34079.0    1
# -49001.0    1
# -31911.0    1
# -58486.0    1
# -17534.0    1
# -10605.0    1
# -43234.0    1
# -19325.0    1
# -45962.0    1
# -46683.0    1
# -57297.0    1
# Name: count, dtype: int64

# %%
# Veo que tengo solamente 20 valores negativos y que
# si los paso a positivos entran dentro de los rangos de la columna ['Salary']
negativos.shape
# Out:
# (20, 16)

# %% [markdown]
# - Tengo solamente 20 valores negativos en Salary de 16737 filas.
# - Los valores negativos si los convierto a positivos entran en los rangos del 'bigote' de la columna 'Salary'.
# - Convertir estos negativos a positivos no va a tener impacto en las estadísticas de la columna.
#
# ***

# %% [markdown]
# - Ahora voy explorar las columnas categóricas y también quiero incluir aquí las columnas categóricas ordinales: Enrollment Year, Enrollment Month, Cancellation Year, Cancellation Month.
#
# - Tengo una función para el analisis de columnas categóricas en el archivo eda_soporte pero, en este caso, no lo voy aplicar porque el tipo de dato de las columnas categóricas ordinales es int ou float.
# Así que, aproveché ese código pero usé solamente un bucle for para esta situación.

# %%
# COLUMNAS CATEGÓRICAS que quiero explorar estadísticamente

df_loyal_cat = df_loyalty[['Province', 'City', 'Gender', 'Education', 'Marital Status', 'Loyalty Card', 'Enrollment Type',
'Enrollment Year', 'Enrollment Month', 'Cancellation Year', 'Cancellation Month']]


for col in df_loyal_cat:
        print(f"____________ {col.upper()} ____________")
        print(f"Moda: {df_loyal_cat[col].mode()[0]}") #[0]para extraer solo el primero valor de moda
        print(f"Valores únicos: {df_loyal_cat[col].nunique()}")
        print(" ")
        print(df_loyal_cat[col].value_counts())

        # COUNT PLOT 
        plt.figure(figsize=(6, 3))
        sns.countplot(y=df_loyal_cat[col],  #invertí los axis para una mejor visualización
                    order=df_loyal_cat[col].value_counts().head(10).index, #añadí un límite de visualización de 10 valores para que el gráfico sea más claro
                    color="skyblue")

        plt.title(f'Countplot — {col}')
        plt.xlabel("Frecuencia")
        plt.ylabel(col)
        plt.tight_layout()
        plt.show()
        print("__________________________________________________________________\n")
# Out:
# ____________ PROVINCE ____________
# Moda: Ontario
# Valores únicos: 11
#
# Province
# Ontario                 5404
# British Columbia        4409
# Quebec                  3300
# Alberta                  969
# Manitoba                 658
# New Brunswick            636
# Nova Scotia              518
# Saskatchewan             409
# Newfoundland             258
# Yukon                    110
# Prince Edward Island      66
# Name: count, dtype: int64
# __________________________________________________________________
#
# ____________ CITY ____________
# Moda: Toronto
# Valores únicos: 29
#
# City
# Toronto           3351
# Vancouver         2582
# Montreal          2059
# Winnipeg           658
# Whistler           582
# Halifax            518
# Ottawa             509
# Trenton            486
# Edmonton           486
# Quebec City        485
# Dawson Creek       444
# Fredericton        425
# Regina             409
# Kingston           401
# Tremblant          398
# ...

# %% [markdown]
# CONCLUSIONES ANALISIS LOYALTY:
# - Hay valores negativos en la columna 'Salary' que voy convertir a positivos.
# - Hay columnas categorizadas como float que deberían ser int: 'Cancellation Year', 'Cancellation Month'.
# - La columna 'Country' apenas contiene 1 valor 'Canada', debe eliminarse porque no nos aporta información útil.
# - No hay duplicados.
# - Hay nulos en las columnas: 'Salary' 25.32%, 'Cancellation Year' 87.65%, 'Cancellation Month' 87.65%.
# - 'Cancellation Year' 87.65%, 'Cancellation Month' 87.65% - es normal tener valores nulos, significa que los clientes no tienen una fecha de cancelación.

# %% [markdown]
# **Juntar los dos dataframes**

# %%
# La columna que tienen en comun es el 'Loyalty Number'

# Hago merge con left join porque quiero mantener todos los datos de df_activity y sumarle los datos de df_royalty
df_merged = pd.merge(df_activity, df_loyalty, on='Loyalty Number', how='left')

# Verifico como quedó
df_merged.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed Country          Province          City  \
# 0                            0  Canada           Alberta      Edmonton
# ...

# %%
# Confirmando si esta unión mantuvo todos los valores "duplicados"
# de la columna 'Loyalty Number'

df_merged[df_merged['Loyalty Number'].duplicated(keep=False)].sort_values("Loyalty Number").head(5)
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 388723          100018  2018     12              17                        6
# 185911          100018  2017     12               6                        0
# 101406          100018  2017      7              10                        0
# 287317          100018  2018      6               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0                   3      1521               152.0                0
# 388723             23      4945               494.0                0
# 185911              6      1908               190.0                0
# 101406             10      3870               387.0                0
# 287317              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed Country Province      City Postal Code  \
# ...

# %% [markdown]
# #### 2. **Limpieza de Datos:**
#    - Elimina o trata los valores nulos, si los hay, en las columnas clave para asegurar que los datos estén completos.
#    - Verifica la consistencia y corrección de los datos para asegurarte de que los datos se presenten de forma coherente.
#    - Realiza cualquier ajuste o conversión necesaria en las columnas (por ejemplo, cambiar tipos de datos) para garantizar la adecuación de los datos para el análisis estadístico.

# %% [markdown]
# - **Negativos**
#     - Tengo solamente 20 valores negativos en Salary de 16737 filas.
#     - Los valores negativos si los convierto a positivos entran en los rangos del 'bigote' de la columna 'Salary'.
#     - Convertir estos negativos a positivos no va a tener impacto en las estadísticas de la columna.

# %%
df_merged['Salary'] = df_merged['Salary'].astype(str).str.replace('-', '').astype(float)

# %%
# Confirmo si se aplicó el cambio a positivos
df_merged['Salary'].min()
# Out:
# 9081.0

# %% [markdown]
# - **Float a Int**

# %%
# Columnas categorizadas como FLOAT converter a INT : 'Cancellation Year', 'Cancellation Month'
columnas_a_int = ["Cancellation Year", "Cancellation Month"]

for c in columnas_a_int:
    df_merged[c] = pd.to_numeric(df_merged[c], errors="coerce")
    
    # Convierto a int
    df_merged[c] = df_merged[c].astype("Int64")

    print(f"La columna '{c}' fue convertida a {df_merged[c].dtypes}")
# Out:
# La columna 'Cancellation Year' fue convertida a Int64
# La columna 'Cancellation Month' fue convertida a Int64

# %% [markdown]
# - **Valor único**

# %%
# La columna 'Country' apenas contiene 1 valor 'Canada', debe eliminarse porque no nos aporta información útil.

df_merged = df_merged.drop(columns=['Country'])
df_merged.head(1)
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
#
#    Dollar Cost Points Redeemed Province      City Postal Code  Gender  \
# 0                            0  Alberta  Edmonton     T9G 1W3  Female
#
#   Education   Salary Marital Status Loyalty Card     CLV Enrollment Type  \
# 0  Bachelor  92552.0        Married       Aurora  7919.2        Standard
#
#    Enrollment Year  Enrollment Month  Cancellation Year  Cancellation Month
# 0             2016                 8               <NA>                <NA>

# %% [markdown]
# - **Nulos**
#     - Cancellation Year' 87.65%, 'Cancellation Month' 87.65% : es normal tener valores nulos aquí, significa que los clientes no tienen una fecha de cancelación. Mantenemos los nulos
#
#     - 'Salary' 25.32%, por ser un valor de nulos elevado lo más seguro y honesto es no imputar los nulos. En este caso, imputarlos podría sesgar la distribución del salario.

# %% [markdown]
# - **Uniformizar nombres de columnas**

# %%
# Se puede uniformizar el nombre de las columnas para que todas sean minúsculas y con "_"

df_merged.columns = df_merged.columns.str.lower().str.replace(' ', '_')

# %%
df_merged.head(1)
# Out:
#    loyalty_number  year  month  flights_booked  flights_with_companions  \
# 0          100018  2017      1               3                        0
#
#    total_flights  distance  points_accumulated  points_redeemed  \
# 0              3      1521               152.0                0
#
#    dollar_cost_points_redeemed province      city postal_code  gender  \
# 0                            0  Alberta  Edmonton     T9G 1W3  Female
#
#   education   salary marital_status loyalty_card     clv enrollment_type  \
# 0  Bachelor  92552.0        Married       Aurora  7919.2        Standard
#
#    enrollment_year  enrollment_month  cancellation_year  cancellation_month
# 0             2016                 8               <NA>                <NA>

# %% [markdown]
# ***

# %% [markdown]
# ### Fase 2: Visualización
#
# Usando las herramientas de visualización que has aprendido durante este módulo, contesta a las siguientes gráficas usando la mejor gráfica que consideres:

# %% [markdown]
# 1. ¿Cómo se distribuye la cantidad de vuelos reservados por mes durante el año?

# %%
# Uso 'month'(variable categórica ordinal) y 'flights_booked'(variable numérica)
# Uso un boxplot para visualizar la distribución de estas variables

plt.figure(figsize=(7,3))
sns.boxplot(data=df_merged, x='month', y='flights_booked', color='mistyrose')
plt.title('Distribución de vuelos reservados por mes')
plt.xlabel('Mes')
plt.ylabel('Vuelos reservados')
plt.grid(True, axis='y', linestyle='-', alpha=0.2)
plt.show()

# %% [markdown]
# - Los meses con aumento significativo de las reservas de vuelos son: Junio, Julio, Agosto y Diciembre.
# - Esto coincide con las épocas festivas de Canadá: vacaciones de verano y de Navidad.

# %% [markdown]
# 2. ¿Existe una relación entre la distancia de los vuelos y los puntos acumulados por los cliente?

# %%
# 'distance' y 'points_accumulated' que son 2 variables numéricas
# Scatterpllot para visualizar si existe correlación
# Regplot para dibujar una línea de tendencia sobre el scatterplot y ayudar validar visualmente si hay correlación

plt.figure(figsize=(7,3))
sns.scatterplot(data=df_merged, x='distance', y='points_accumulated', alpha=0.5, color='tan')
sns.regplot(data=df_merged, x='distance', y='points_accumulated', scatter=False, color='maroon')
plt.title('Relación entre distancia del vuelo y puntos acumulados')
plt.xlabel('Distancia del vuelo')
plt.ylabel('Puntos acumulados')
plt.show()

# %% [markdown]
# - Hay una correlación positiva entre la distancia de los vuelos y los puntos acumulados. Eso quiere decir que cuanto más larga sea la distancia más puntos va a generar para el cliente.

# %% [markdown]
# 3. ¿Cuál es la distribución de los clientes por provincia o estado?

# %%
# Podía resolver este ejercício con un Countplot pero para la interpretación de datos me resulta más simples ver el peso de cada categoria por porcentajes
# Uso 'province' y calculo el porcentaje de clientes por cada provincia
# Barplot para representar los valores de porcentaje

porcent = round(df_merged['province'].value_counts(normalize=True) * 100, 2)

plt.figure(figsize=(12,6))
sns.barplot(x=porcent.values, y=porcent.index, hue=porcent.values, palette='Set2')

plt.title('Distribución de clientes por provincia (%)')
plt.xlabel('Porcentaje de clientes (%)')
plt.ylabel('Provincia')
plt.legend().remove()
plt.grid(True, axis='x', linestyle='-', alpha=0.2)
plt.show()

# %% [markdown]
# - Podemos observar una concentración geográfica muy fuerte en Ontario, British Columbia y Quebec - con alrededor del 80% de los clientes.
# - Las provincias con menor número de clientes son: Saskatchewan, Newfoundland, Yukon y Prince Edward Island - todas con menos del 3%.
# - Esto indica que la aerolínea tiene sus clientes muy concentrados en áreas urbanas grandes, probablemente porque es donde hay mayor movilidad y aeropuertos importantes.

# %% [markdown]
# 4. ¿Cómo se compara el salario promedio entre los diferentes niveles educativos de los clientes?

# %%
# Primero agrupo los datos para poder calcular el promedio salarial en los vários niveles educativos
# Ordeno de forma descendente de salario + alto a más bajo
# Despues represento ese calculo en un barplot

avg_salary = df_merged.groupby('education')['salary'].mean().reset_index().sort_values(by='salary', ascending=False)

plt.figure(figsize=(8,4))
sns.barplot(data=avg_salary, x='education', y='salary', hue='education', palette='BuPu')

plt.title('Salario promedio por nivel educativo')
plt.xlabel('Nivel educativo')
plt.ylabel('Salario promedio')
plt.xticks(rotation=45)
plt.show()

# %%
df_merged['education'].value_counts()
# Out:
# education
# Bachelor                253752
# College                 102672
# High School or Below     19008
# Doctor                   17856
# Master                   12336
# Name: count, dtype: int64

# %% [markdown]
# - Hay una correlación positiva entre el nível de estudios y el salario promedio. Cuanto mayor la educación, mayor es su sueldo
# - Hay 102672 clientes con el grado educativo 'college' pero no hay datos de sus salario.

# %% [markdown]
# 5. ¿Cuál es la proporción de clientes con diferentes tipos de tarjetas de fidelidad?

# %%
df_merged.columns
# Out:
# Index(['loyalty_number', 'year', 'month', 'flights_booked',
#        'flights_with_companions', 'total_flights', 'distance',
#        'points_accumulated', 'points_redeemed', 'dollar_cost_points_redeemed',
#        'province', 'city', 'postal_code', 'gender', 'education', 'salary',
#        'marital_status', 'loyalty_card', 'clv', 'enrollment_type',
#        'enrollment_year', 'enrollment_month', 'cancellation_year',
#        'cancellation_month'],
#       dtype='object')

# %%
# calculo los porcentajes de cada tipo de tarjeta de la columna 'loyalty_card'
# represento en un pie chart para visualizar
tarj_porcent = round(df_merged['loyalty_card'].value_counts(normalize=True) * 100, 2)

# Crear gráfico de pastel
plt.figure(figsize=(4,4))
colores = ['lemonchiffon', 'goldenrod', 'gold']
plt.pie(tarj_porcent, labels=tarj_porcent.index, autopct='%1.1f%%', colors=colores)
plt.title('Porcentaje de clientes por tipo de tarjeta de fidelidad')
plt.show()

# %% [markdown]
# - 45.4% de los clientes tienen la tarjeta de fidelidad 'Star', 33.9% tienen la tarjeta Nova y apenas 20.7% tienen la tarjeta de fidelidad Aurora.

# %% [markdown]
# 6. ¿Cómo se distribuyen los clientes según su estado civil y género?

# %%
# Como se tratan de 2 variables categóricas voy usar una tabla de contingencias para observar la distribución
# Me gusta más ver los resultados en % para entender mejor el peso de cada categoria

conting = (pd.crosstab(df_merged['marital_status'], df_merged['gender'], normalize='index') * 100).round(2)
conting
# Out:
# gender          Female   Male
# marital_status
# Divorced         50.49  49.51
# Married          49.96  50.04
# Single           50.56  49.44

# %%
conting.plot(kind='barh', figsize=(6,4), colormap='Paired')
plt.ylabel('Estado civil')
plt.title('Distribución de género por estado civil')
plt.xlabel('Porcentaje (%)')
plt.legend(title='Género', bbox_to_anchor=(1, 1))
plt.show()

# %% [markdown]
# - De los clientes divorciados 50% son mujeres y otros 50% son hombres.
# - Se puede observar el mismo padrón en las várias combinaciones de categorias.
# - Podemos concluir que no hay un estado civil dominado por un género en particular, todos los porcentajes rondan el 50%.
